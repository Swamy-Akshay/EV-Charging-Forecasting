# %%
#1. Import Libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error, r2_score, classification_report
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
file_path = r"d:\IARE\The Project\Review 3\Codes\ev_charging_patterns_augmented.csv"
df = pd.read_csv(file_path)

# %%
df.dropna(subset=["Energy Consumed (kWh)", "Charging Duration (hours)", "Charging Rate (kW)", "Temperature (°C)"], inplace=True)

# %%
categorical_cols = ["Vehicle Model", "Charging Station Location", "Time of Day", "Day of Week", "Charger Type", "User Type"]
label_encoders = {col: LabelEncoder().fit(df[col]) for col in categorical_cols}
for col in categorical_cols:
    df[col] = label_encoders[col].transform(df[col])

# %%
df["Charging Start Time"] = pd.to_datetime(df["Charging Start Time"], dayfirst=True, errors='coerce')
df = df.dropna(subset=["Charging Start Time"])
df["Charging Hour"] = df["Charging Start Time"].dt.hour
df.drop(columns=["User ID", "Charging Station ID", "Charging Start Time", "Charging End Time"], inplace=True)

# %%
target = "Energy Consumed (kWh)"
features = ["Battery Capacity (kWh)", "Charging Duration (hours)", "Charging Rate (kW)", 
            "Charging Hour", "Time of Day", "Day of Week", "Temperature (°C)"]

# %%
scaler = StandardScaler()
df[features] = scaler.fit_transform(df[features])

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# %%
X_train_seq = X_train.values.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_seq = X_test.values.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-4)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
import time

def build_and_train_model(model_type, X_train, y_train, X_test, y_test):
    start_time = time.time()
    model = Sequential()
    if model_type == "ANN":
        model.add(Dense(128, activation="relu", input_shape=(X_train.shape[1],)))
        model.add(Dense(64, activation="relu"))
        model.add(Dense(32, activation="relu"))
        model.add(Dense(1))
    elif model_type == "RNN":
        model.add(SimpleRNN(128, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], 1)))
        model.add(Dropout(0.3))
        model.add(SimpleRNN(64, activation="relu"))
        model.add(Dense(32, activation="relu"))
        model.add(Dense(1))
    elif model_type == "LSTM":
        model.add(Bidirectional(LSTM(128, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], 1))))
        model.add(Dropout(0.3))
        model.add(Bidirectional(LSTM(64, activation="relu")))
        model.add(Dense(32, activation="relu"))
        model.add(Dense(1))
    elif model_type == "GRU":
        model.add(Bidirectional(GRU(128, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], 1))))
        model.add(Dropout(0.3))
        model.add(Bidirectional(GRU(64, activation="relu")))
        model.add(Dense(32, activation="relu"))
        model.add(Dense(1))
    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss="mse")
    model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test),
              verbose=1, callbacks=[lr_scheduler, early_stopping])
    elapsed_time = time.time() - start_time
    print(f"{model_type} training time: {elapsed_time:.2f} seconds")
    return model.predict(X_test), elapsed_time

# %%
y_pred_ann, ann_time = build_and_train_model("ANN", X_train, y_train, X_test, y_test)
y_pred_rnn, rnn_time = build_and_train_model("RNN", X_train_seq, y_train, X_test_seq, y_test)
y_pred_lstm, lstm_time = build_and_train_model("LSTM", X_train_seq, y_train, X_test_seq, y_test)
y_pred_gru, gru_time = build_and_train_model("GRU", X_train_seq, y_train, X_test_seq, y_test)
# Out:
# Epoch 1/100
# c:\Users\Samrat Dudgundi\Anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 2022.7698 - val_loss: 569.8619 - learning_rate: 0.0010
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 525.9066 - val_loss: 550.3895 - learning_rate: 0.0010
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 510.6829 - val_loss: 539.7965 - learning_rate: 0.0010
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 503.8195 - val_loss: 534.6407 - learning_rate: 0.0010
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 490.9187 - val_loss: 531.7031 - learning_rate: 0.0010
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 479.1823 - val_loss: 528.5015 - learning_rate: 0.0010
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 478.7801 - val_loss: 527.4429 - learning_rate: 0.0010
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 481.5415 - val_loss: 524.5319 - learning_rate: 0.0010
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 492.3130 - val_loss: 521.1464 - learning_rate: 0.0010
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 484.9444 - val_loss: 518.6166 - learning_rate: 0.0010
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 481.9234 - val_loss: 517.3063 - learning_rate: 0.0010
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 480.7198 - val_loss: 519.3051 - learning_rate: 0.0010
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 503.1775 - val_loss: 515.4286 - learning_rate: 0.0010
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 485.2280 - val_loss: 510.6423 - learning_rate: 0.0010
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 487.6547 - val_loss: 512.1205 - learning_rate: 0.0010
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 494.5023 - val_loss: 511.7985 - learning_rate: 0.0010
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 478.7979 - val_loss: 513.7178 - learning_rate: 0.0010
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 485.5524 - val_loss: 517.7054 - learning_rate: 0.0010
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 471.0772 - val_loss: 506.2263 - learning_rate: 0.0010
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 476.6334 - val_loss: 506.2148 - learning_rate: 0.0010
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 458.1491 - val_loss: 509.7995 - learning_rate: 0.0010
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 461.6975 - val_loss: 508.0117 - learning_rate: 0.0010
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 470.6752 - val_loss: 503.1865 - learning_rate: 0.0010
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 476.1076 - val_loss: 509.8260 - learning_rate: 0.0010
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 468.1566 - val_loss: 502.9638 - learning_rate: 0.0010
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 471.0802 - val_loss: 506.7291 - learning_rate: 0.0010
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 452.8247 - val_loss: 499.8418 - learning_rate: 0.0010
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 463.0160 - val_loss: 496.8062 - learning_rate: 0.0010
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 468.5285 - val_loss: 496.2063 - learning_rate: 0.0010
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 465.2745 - val_loss: 493.2369 - learning_rate: 0.0010
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 464.9649 - val_loss: 499.1328 - learning_rate: 0.0010
# Epoch 32/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 458.6530 - val_loss: 496.5892 - learning_rate: 0.0010
# Epoch 33/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 452.6179 - val_loss: 492.2450 - learning_rate: 0.0010
# Epoch 34/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 455.3979 - val_loss: 494.0813 - learning_rate: 0.0010
# Epoch 35/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 442.8920 - val_loss: 490.4146 - learning_rate: 0.0010
# Epoch 36/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 442.5593 - val_loss: 492.8195 - learning_rate: 0.0010
# Epoch 37/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 442.0370 - val_loss: 501.2592 - learning_rate: 0.0010
# Epoch 38/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 449.7942 - val_loss: 486.1304 - learning_rate: 0.0010
# Epoch 39/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 426.4896 - val_loss: 486.3984 - learning_rate: 0.0010
# Epoch 40/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 445.9856 - val_loss: 486.8046 - learning_rate: 0.0010
# Epoch 41/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 423.0265 - val_loss: 490.0782 - learning_rate: 0.0010
# Epoch 42/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 425.3270 - val_loss: 496.0303 - learning_rate: 0.0010
# Epoch 43/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 436.0580 - val_loss: 485.2390 - learning_rate: 0.0010
# Epoch 44/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 430.0896 - val_loss: 486.8760 - learning_rate: 0.0010
# Epoch 45/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 419.5231 - val_loss: 481.4027 - learning_rate: 0.0010
# Epoch 46/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 417.8157 - val_loss: 490.1006 - learning_rate: 0.0010
# Epoch 47/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 425.9939 - val_loss: 485.6556 - learning_rate: 0.0010
# Epoch 48/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 429.4655 - val_loss: 480.9914 - learning_rate: 0.0010
# Epoch 49/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 425.1866 - val_loss: 479.7877 - learning_rate: 0.0010
# Epoch 50/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 418.7791 - val_loss: 480.7995 - learning_rate: 0.0010
# Epoch 51/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 408.8971 - val_loss: 480.8444 - learning_rate: 0.0010
# Epoch 52/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 422.4328 - val_loss: 489.3896 - learning_rate: 0.0010
# Epoch 53/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 416.0403 - val_loss: 475.9615 - learning_rate: 0.0010
# Epoch 54/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 414.1840 - val_loss: 485.5446 - learning_rate: 0.0010
# Epoch 55/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 419.9873 - val_loss: 480.7078 - learning_rate: 0.0010
# Epoch 56/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 419.5665 - val_loss: 479.6271 - learning_rate: 0.0010
# Epoch 57/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 395.4659 - val_loss: 478.9644 - learning_rate: 0.0010
# Epoch 58/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 410.2088 - val_loss: 479.8799 - learning_rate: 0.0010
# Epoch 59/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 410.4327 - val_loss: 478.4344 - learning_rate: 5.0000e-04
# Epoch 60/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 416.2474 - val_loss: 477.0431 - learning_rate: 5.0000e-04
# Epoch 61/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 410.2263 - val_loss: 477.7138 - learning_rate: 5.0000e-04
# Epoch 62/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 399.0212 - val_loss: 478.3874 - learning_rate: 5.0000e-04
# Epoch 63/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 406.6676 - val_loss: 478.6120 - learning_rate: 5.0000e-04
# ANN training time: 37.65 seconds
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 1/100
# c:\Users\Samrat Dudgundi\Anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1349.4703 - val_loss: 639.3033 - learning_rate: 0.0010
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 542.7113 - val_loss: 514.0070 - learning_rate: 0.0010
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 508.6925 - val_loss: 570.6891 - learning_rate: 0.0010
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 509.7988 - val_loss: 505.2113 - learning_rate: 0.0010
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 473.4536 - val_loss: 505.7448 - learning_rate: 0.0010
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 497.6781 - val_loss: 553.3844 - learning_rate: 0.0010
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 538.6805 - val_loss: 497.8375 - learning_rate: 0.0010
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 482.7914 - val_loss: 553.8582 - learning_rate: 0.0010
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 506.0306 - val_loss: 502.7203 - learning_rate: 0.0010
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 486.5970 - val_loss: 507.8631 - learning_rate: 0.0010
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 486.6266 - val_loss: 492.8493 - learning_rate: 0.0010
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 474.0812 - val_loss: 580.1049 - learning_rate: 0.0010
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 503.3311 - val_loss: 489.6453 - learning_rate: 0.0010
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 447.5173 - val_loss: 486.5132 - learning_rate: 0.0010
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 502.8796 - val_loss: 497.6518 - learning_rate: 0.0010
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 463.9300 - val_loss: 483.7797 - learning_rate: 0.0010
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 449.7016 - val_loss: 504.7769 - learning_rate: 0.0010
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 466.7188 - val_loss: 513.3410 - learning_rate: 0.0010
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 484.1833 - val_loss: 525.0399 - learning_rate: 0.0010
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 458.1574 - val_loss: 480.4773 - learning_rate: 0.0010
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 450.8568 - val_loss: 474.6734 - learning_rate: 0.0010
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 462.2163 - val_loss: 473.1039 - learning_rate: 0.0010
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 447.1346 - val_loss: 486.4911 - learning_rate: 0.0010
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 480.7397 - val_loss: 475.9660 - learning_rate: 0.0010
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 444.1882 - val_loss: 488.0649 - learning_rate: 0.0010
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 455.5571 - val_loss: 565.7627 - learning_rate: 0.0010
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 462.9748 - val_loss: 471.7011 - learning_rate: 0.0010
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 448.9731 - val_loss: 463.1794 - learning_rate: 0.0010
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 434.5600 - val_loss: 525.8723 - learning_rate: 0.0010
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 461.9798 - val_loss: 456.2755 - learning_rate: 0.0010
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 416.0339 - val_loss: 458.3957 - learning_rate: 0.0010
# Epoch 32/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 425.6624 - val_loss: 493.5470 - learning_rate: 0.0010
# Epoch 33/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 430.5311 - val_loss: 542.2850 - learning_rate: 0.0010
# Epoch 34/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 508.3042 - val_loss: 458.7495 - learning_rate: 0.0010
# Epoch 35/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 421.1348 - val_loss: 460.6753 - learning_rate: 0.0010
# Epoch 36/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 403.5970 - val_loss: 450.8757 - learning_rate: 5.0000e-04
# Epoch 37/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 413.3439 - val_loss: 448.7901 - learning_rate: 5.0000e-04
# Epoch 38/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 388.8234 - val_loss: 446.3029 - learning_rate: 5.0000e-04
# Epoch 39/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 379.3120 - val_loss: 446.5476 - learning_rate: 5.0000e-04
# Epoch 40/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 376.4257 - val_loss: 456.4961 - learning_rate: 5.0000e-04
# Epoch 41/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 388.3071 - val_loss: 438.1142 - learning_rate: 5.0000e-04
# Epoch 42/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 384.8392 - val_loss: 448.3476 - learning_rate: 5.0000e-04
# Epoch 43/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 377.6455 - val_loss: 457.3352 - learning_rate: 5.0000e-04
# Epoch 44/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 398.2478 - val_loss: 435.5432 - learning_rate: 5.0000e-04
# Epoch 45/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 366.1823 - val_loss: 440.4647 - learning_rate: 5.0000e-04
# Epoch 46/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 357.0561 - val_loss: 448.1513 - learning_rate: 5.0000e-04
# Epoch 47/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 341.3455 - val_loss: 437.4127 - learning_rate: 5.0000e-04
# Epoch 48/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 360.2698 - val_loss: 452.6964 - learning_rate: 5.0000e-04
# Epoch 49/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 355.9455 - val_loss: 448.9535 - learning_rate: 5.0000e-04
# Epoch 50/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 329.5711 - val_loss: 430.2970 - learning_rate: 2.5000e-04
# Epoch 51/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 321.0186 - val_loss: 425.7973 - learning_rate: 2.5000e-04
# Epoch 52/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 349.4549 - val_loss: 431.1167 - learning_rate: 2.5000e-04
# Epoch 53/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 340.6787 - val_loss: 431.1921 - learning_rate: 2.5000e-04
# Epoch 54/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 332.6483 - val_loss: 429.4782 - learning_rate: 2.5000e-04
# Epoch 55/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 324.1874 - val_loss: 429.9813 - learning_rate: 2.5000e-04
# Epoch 56/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 330.5411 - val_loss: 431.7353 - learning_rate: 2.5000e-04
# Epoch 57/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 332.1933 - val_loss: 427.3835 - learning_rate: 1.2500e-04
# Epoch 58/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 316.7163 - val_loss: 430.0695 - learning_rate: 1.2500e-04
# Epoch 59/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 310.9761 - val_loss: 424.1189 - learning_rate: 1.2500e-04
# Epoch 60/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 335.6437 - val_loss: 429.3853 - learning_rate: 1.2500e-04
# Epoch 61/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 327.6228 - val_loss: 428.2269 - learning_rate: 1.2500e-04
# Epoch 62/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 306.8997 - val_loss: 426.1906 - learning_rate: 1.2500e-04
# Epoch 63/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 297.6386 - val_loss: 427.5157 - learning_rate: 1.2500e-04
# Epoch 64/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 307.0823 - val_loss: 429.3488 - learning_rate: 1.2500e-04
# Epoch 65/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 310.5386 - val_loss: 426.7759 - learning_rate: 1.0000e-04
# Epoch 66/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 310.8498 - val_loss: 427.6760 - learning_rate: 1.0000e-04
# Epoch 67/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 308.9736 - val_loss: 425.4295 - learning_rate: 1.0000e-04
# Epoch 68/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 316.3519 - val_loss: 427.0840 - learning_rate: 1.0000e-04
# Epoch 69/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 308.4395 - val_loss: 426.1556 - learning_rate: 1.0000e-04
# RNN training time: 96.06 seconds
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Epoch 1/100
# c:\Users\Samrat Dudgundi\Anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - loss: 1432.0348 - val_loss: 513.7450 - learning_rate: 0.0010
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 492.6299 - val_loss: 510.5517 - learning_rate: 0.0010
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 514.9786 - val_loss: 571.8292 - learning_rate: 0.0010
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 69s 628ms/step - loss: 495.1979 - val_loss: 541.9871 - learning_rate: 0.0010
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 497.5701 - val_loss: 505.5042 - learning_rate: 0.0010
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 491.6252 - val_loss: 517.0480 - learning_rate: 0.0010
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 491.7972 - val_loss: 505.0636 - learning_rate: 0.0010
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 503.3193 - val_loss: 516.4399 - learning_rate: 0.0010
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 465.1320 - val_loss: 523.6998 - learning_rate: 0.0010
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 495.5775 - val_loss: 533.9018 - learning_rate: 0.0010
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 487.5290 - val_loss: 514.3338 - learning_rate: 0.0010
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 487.5790 - val_loss: 504.2994 - learning_rate: 0.0010
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 487.1472 - val_loss: 511.2954 - learning_rate: 0.0010
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 494.5501 - val_loss: 508.1224 - learning_rate: 0.0010
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 493.3314 - val_loss: 512.1545 - learning_rate: 0.0010
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 479.0032 - val_loss: 508.3534 - learning_rate: 0.0010
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 484.5586 - val_loss: 516.2929 - learning_rate: 0.0010
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 506.1331 - val_loss: 503.5690 - learning_rate: 5.0000e-04
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 479.1813 - val_loss: 503.8009 - learning_rate: 5.0000e-04
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 487.5964 - val_loss: 503.9279 - learning_rate: 5.0000e-04
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 478.5446 - val_loss: 503.6793 - learning_rate: 5.0000e-04
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 474.9867 - val_loss: 504.3536 - learning_rate: 5.0000e-04
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 479.1093 - val_loss: 508.8453 - learning_rate: 5.0000e-04
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 487.8249 - val_loss: 504.2613 - learning_rate: 2.5000e-04
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 467.9373 - val_loss: 505.5553 - learning_rate: 2.5000e-04
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 507.6555 - val_loss: 505.4262 - learning_rate: 2.5000e-04
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 493.7022 - val_loss: 503.6135 - learning_rate: 2.5000e-04
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 495.2927 - val_loss: 502.7273 - learning_rate: 2.5000e-04
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 477.7109 - val_loss: 502.7571 - learning_rate: 2.5000e-04
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 481.5045 - val_loss: 503.2626 - learning_rate: 2.5000e-04
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 496.4318 - val_loss: 502.6598 - learning_rate: 2.5000e-04
# Epoch 32/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 493.5572 - val_loss: 504.2664 - learning_rate: 2.5000e-04
# Epoch 33/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 483.3400 - val_loss: 504.4807 - learning_rate: 2.5000e-04
# Epoch 34/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 477.7028 - val_loss: 502.9052 - learning_rate: 2.5000e-04
# Epoch 35/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 484.2763 - val_loss: 503.5302 - learning_rate: 2.5000e-04
# Epoch 36/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 479.7770 - val_loss: 502.2586 - learning_rate: 2.5000e-04
# Epoch 37/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 491.1314 - val_loss: 502.6856 - learning_rate: 2.5000e-04
# Epoch 38/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 484.1964 - val_loss: 503.0517 - learning_rate: 2.5000e-04
# Epoch 39/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 468.2455 - val_loss: 501.9431 - learning_rate: 2.5000e-04
# Epoch 40/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 485.2031 - val_loss: 501.7671 - learning_rate: 2.5000e-04
# Epoch 41/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 482.8158 - val_loss: 504.3119 - learning_rate: 2.5000e-04
# Epoch 42/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 470.6091 - val_loss: 502.2668 - learning_rate: 2.5000e-04
# Epoch 43/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 466.5220 - val_loss: 502.0388 - learning_rate: 2.5000e-04
# Epoch 44/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 490.3235 - val_loss: 503.2523 - learning_rate: 2.5000e-04
# Epoch 45/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 487.3749 - val_loss: 501.9903 - learning_rate: 2.5000e-04
# Epoch 46/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 465.2078 - val_loss: 501.7455 - learning_rate: 1.2500e-04
# Epoch 47/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 472.3957 - val_loss: 501.5719 - learning_rate: 1.2500e-04
# Epoch 48/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 487.5385 - val_loss: 501.7086 - learning_rate: 1.2500e-04
# Epoch 49/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 478.8948 - val_loss: 501.4974 - learning_rate: 1.2500e-04
# Epoch 50/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 475.6321 - val_loss: 501.8539 - learning_rate: 1.2500e-04
# Epoch 51/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 488.9108 - val_loss: 501.8228 - learning_rate: 1.2500e-04
# Epoch 52/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 491.5928 - val_loss: 501.1759 - learning_rate: 1.2500e-04
# Epoch 53/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 460.0137 - val_loss: 500.9962 - learning_rate: 1.2500e-04
# Epoch 54/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 474.1227 - val_loss: 501.5761 - learning_rate: 1.2500e-04
# Epoch 55/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 485.5055 - val_loss: 500.9792 - learning_rate: 1.2500e-04
# Epoch 56/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 477.0322 - val_loss: 501.0305 - learning_rate: 1.2500e-04
# Epoch 57/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 464.4816 - val_loss: 503.7834 - learning_rate: 1.2500e-04
# Epoch 58/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 472.3952 - val_loss: 501.7820 - learning_rate: 1.2500e-04
# Epoch 59/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 473.4075 - val_loss: 501.1757 - learning_rate: 1.2500e-04
# Epoch 60/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 488.1771 - val_loss: 500.4986 - learning_rate: 1.2500e-04
# Epoch 61/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 483.3443 - val_loss: 502.9837 - learning_rate: 1.2500e-04
# Epoch 62/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 471.5372 - val_loss: 500.4469 - learning_rate: 1.2500e-04
# Epoch 63/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 476.1919 - val_loss: 500.6401 - learning_rate: 1.2500e-04
# Epoch 64/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 469.6718 - val_loss: 502.3671 - learning_rate: 1.2500e-04
# Epoch 65/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 463.6568 - val_loss: 501.1406 - learning_rate: 1.2500e-04
# Epoch 66/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 489.2999 - val_loss: 500.2079 - learning_rate: 1.2500e-04
# Epoch 67/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 466.6925 - val_loss: 500.5038 - learning_rate: 1.2500e-04
# Epoch 68/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 470.7415 - val_loss: 500.0728 - learning_rate: 1.2500e-04
# Epoch 69/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 472.9716 - val_loss: 500.2798 - learning_rate: 1.2500e-04
# Epoch 70/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 457.0882 - val_loss: 499.8469 - learning_rate: 1.2500e-04
# Epoch 71/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 488.9279 - val_loss: 500.7570 - learning_rate: 1.2500e-04
# Epoch 72/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 470.2217 - val_loss: 500.6544 - learning_rate: 1.2500e-04
# Epoch 73/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 477.0527 - val_loss: 500.7287 - learning_rate: 1.2500e-04
# Epoch 74/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 473.9398 - val_loss: 500.9262 - learning_rate: 1.2500e-04
# Epoch 75/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 467.6153 - val_loss: 501.5749 - learning_rate: 1.2500e-04
# Epoch 76/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 481.0745 - val_loss: 499.8459 - learning_rate: 1.0000e-04
# Epoch 77/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 468.9030 - val_loss: 499.6521 - learning_rate: 1.0000e-04
# Epoch 78/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 477.8827 - val_loss: 499.8650 - learning_rate: 1.0000e-04
# Epoch 79/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 466.7486 - val_loss: 500.0997 - learning_rate: 1.0000e-04
# Epoch 80/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 481.1646 - val_loss: 499.5785 - learning_rate: 1.0000e-04
# Epoch 81/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 444.8572 - val_loss: 499.5767 - learning_rate: 1.0000e-04
# Epoch 82/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 492.4480 - val_loss: 500.7584 - learning_rate: 1.0000e-04
# Epoch 83/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 473.3019 - val_loss: 499.7068 - learning_rate: 1.0000e-04
# Epoch 84/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 474.2679 - val_loss: 501.1540 - learning_rate: 1.0000e-04
# Epoch 85/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 474.3369 - val_loss: 499.9805 - learning_rate: 1.0000e-04
# Epoch 86/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 473.9288 - val_loss: 499.2616 - learning_rate: 1.0000e-04
# Epoch 87/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 465.1809 - val_loss: 499.6226 - learning_rate: 1.0000e-04
# Epoch 88/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 472.2498 - val_loss: 499.2814 - learning_rate: 1.0000e-04
# Epoch 89/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 477.6640 - val_loss: 499.4712 - learning_rate: 1.0000e-04
# Epoch 90/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 466.6117 - val_loss: 500.9933 - learning_rate: 1.0000e-04
# Epoch 91/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 478.4591 - val_loss: 499.2068 - learning_rate: 1.0000e-04
# Epoch 92/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 472.2542 - val_loss: 499.7630 - learning_rate: 1.0000e-04
# Epoch 93/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 471.0414 - val_loss: 498.5291 - learning_rate: 1.0000e-04
# Epoch 94/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 464.1445 - val_loss: 499.4365 - learning_rate: 1.0000e-04
# Epoch 95/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 472.7214 - val_loss: 500.5247 - learning_rate: 1.0000e-04
# Epoch 96/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 463.1140 - val_loss: 499.5209 - learning_rate: 1.0000e-04
# Epoch 97/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 487.5813 - val_loss: 499.1862 - learning_rate: 1.0000e-04
# Epoch 98/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 458.6385 - val_loss: 500.0079 - learning_rate: 1.0000e-04
# Epoch 99/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 488.9818 - val_loss: 499.3674 - learning_rate: 1.0000e-04
# Epoch 100/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 471.7410 - val_loss: 501.0204 - learning_rate: 1.0000e-04
# LSTM training time: 292.82 seconds
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step
# Epoch 1/100
# c:\Users\Samrat Dudgundi\Anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - loss: 1405.8346 - val_loss: 514.6389 - learning_rate: 0.0010
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 501.8940 - val_loss: 508.5057 - learning_rate: 0.0010
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 500.6786 - val_loss: 514.3491 - learning_rate: 0.0010
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 483.2015 - val_loss: 506.6125 - learning_rate: 0.0010
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 509.1072 - val_loss: 520.1957 - learning_rate: 0.0010
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 493.7298 - val_loss: 504.3867 - learning_rate: 0.0010
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 481.2671 - val_loss: 503.0828 - learning_rate: 0.0010
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 475.0073 - val_loss: 502.0872 - learning_rate: 0.0010
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 480.0764 - val_loss: 501.2188 - learning_rate: 0.0010
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 472.8883 - val_loss: 542.6003 - learning_rate: 0.0010
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 492.2004 - val_loss: 509.3577 - learning_rate: 0.0010
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 470.2433 - val_loss: 501.5236 - learning_rate: 0.0010
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 482.7387 - val_loss: 503.4367 - learning_rate: 0.0010
# Epoch 14/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 495.8646 - val_loss: 510.5396 - learning_rate: 0.0010
# Epoch 15/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 477.0282 - val_loss: 500.4821 - learning_rate: 5.0000e-04
# Epoch 16/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 480.0374 - val_loss: 506.0534 - learning_rate: 5.0000e-04
# Epoch 17/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 486.7783 - val_loss: 508.4460 - learning_rate: 5.0000e-04
# Epoch 18/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 469.7832 - val_loss: 499.1851 - learning_rate: 5.0000e-04
# Epoch 19/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 472.6632 - val_loss: 498.0303 - learning_rate: 5.0000e-04
# Epoch 20/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 483.9994 - val_loss: 498.8596 - learning_rate: 5.0000e-04
# Epoch 21/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 469.5581 - val_loss: 500.6110 - learning_rate: 5.0000e-04
# Epoch 22/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 482.6414 - val_loss: 496.3781 - learning_rate: 5.0000e-04
# Epoch 23/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 471.6917 - val_loss: 496.4913 - learning_rate: 5.0000e-04
# Epoch 24/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 468.7173 - val_loss: 501.9925 - learning_rate: 5.0000e-04
# Epoch 25/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 493.7647 - val_loss: 494.5485 - learning_rate: 5.0000e-04
# Epoch 26/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 477.4229 - val_loss: 494.8686 - learning_rate: 5.0000e-04
# Epoch 27/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 476.7527 - val_loss: 495.3252 - learning_rate: 5.0000e-04
# Epoch 28/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 466.0573 - val_loss: 502.5709 - learning_rate: 5.0000e-04
# Epoch 29/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 471.7828 - val_loss: 493.1436 - learning_rate: 5.0000e-04
# Epoch 30/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 482.9677 - val_loss: 493.4089 - learning_rate: 5.0000e-04
# Epoch 31/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 453.3369 - val_loss: 492.7476 - learning_rate: 5.0000e-04
# Epoch 32/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 472.0041 - val_loss: 491.5473 - learning_rate: 5.0000e-04
# Epoch 33/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 472.2887 - val_loss: 494.8836 - learning_rate: 5.0000e-04
# Epoch 34/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 479.5918 - val_loss: 492.3287 - learning_rate: 5.0000e-04
# Epoch 35/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 480.7073 - val_loss: 491.0652 - learning_rate: 5.0000e-04
# Epoch 36/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 477.1019 - val_loss: 492.6492 - learning_rate: 5.0000e-04
# Epoch 37/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 450.1094 - val_loss: 494.0378 - learning_rate: 5.0000e-04
# Epoch 38/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 477.0931 - val_loss: 493.3073 - learning_rate: 5.0000e-04
# Epoch 39/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 450.9960 - val_loss: 492.4615 - learning_rate: 5.0000e-04
# Epoch 40/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 469.5204 - val_loss: 499.4436 - learning_rate: 5.0000e-04
# Epoch 41/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 468.7744 - val_loss: 490.7307 - learning_rate: 2.5000e-04
# Epoch 42/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 452.0571 - val_loss: 489.0958 - learning_rate: 2.5000e-04
# Epoch 43/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 471.8860 - val_loss: 490.4165 - learning_rate: 2.5000e-04
# Epoch 44/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 447.4152 - val_loss: 491.5528 - learning_rate: 2.5000e-04
# Epoch 45/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 455.0096 - val_loss: 485.9597 - learning_rate: 2.5000e-04
# Epoch 46/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 472.3919 - val_loss: 486.5210 - learning_rate: 2.5000e-04
# Epoch 47/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 467.4763 - val_loss: 485.5856 - learning_rate: 2.5000e-04
# Epoch 48/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 453.9472 - val_loss: 485.7523 - learning_rate: 2.5000e-04
# Epoch 49/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 460.2896 - val_loss: 486.9969 - learning_rate: 2.5000e-04
# Epoch 50/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 453.7533 - val_loss: 485.6384 - learning_rate: 2.5000e-04
# Epoch 51/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 460.6214 - val_loss: 485.3428 - learning_rate: 2.5000e-04
# Epoch 52/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 458.0735 - val_loss: 484.1792 - learning_rate: 2.5000e-04
# Epoch 53/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 451.2968 - val_loss: 484.4111 - learning_rate: 2.5000e-04
# Epoch 54/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 453.5151 - val_loss: 484.4352 - learning_rate: 2.5000e-04
# Epoch 55/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 440.8680 - val_loss: 488.0229 - learning_rate: 2.5000e-04
# Epoch 56/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 470.0663 - val_loss: 483.5534 - learning_rate: 2.5000e-04
# Epoch 57/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 448.9432 - val_loss: 482.6926 - learning_rate: 2.5000e-04
# Epoch 58/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 452.9938 - val_loss: 482.6863 - learning_rate: 2.5000e-04
# Epoch 59/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 442.4895 - val_loss: 485.3493 - learning_rate: 2.5000e-04
# Epoch 60/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 460.9100 - val_loss: 483.0208 - learning_rate: 2.5000e-04
# Epoch 61/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 455.6435 - val_loss: 483.8204 - learning_rate: 2.5000e-04
# Epoch 62/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 458.9536 - val_loss: 484.8478 - learning_rate: 2.5000e-04
# Epoch 63/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 448.5762 - val_loss: 480.8819 - learning_rate: 2.5000e-04
# Epoch 64/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 450.9006 - val_loss: 484.2569 - learning_rate: 2.5000e-04
# Epoch 65/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 458.0915 - val_loss: 480.3466 - learning_rate: 2.5000e-04
# Epoch 66/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 441.2554 - val_loss: 480.4712 - learning_rate: 2.5000e-04
# Epoch 67/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 452.4847 - val_loss: 482.8869 - learning_rate: 2.5000e-04
# Epoch 68/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 450.0215 - val_loss: 481.6868 - learning_rate: 2.5000e-04
# Epoch 69/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 445.2423 - val_loss: 484.4283 - learning_rate: 2.5000e-04
# Epoch 70/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 442.8816 - val_loss: 481.6025 - learning_rate: 2.5000e-04
# Epoch 71/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 431.9486 - val_loss: 479.8713 - learning_rate: 1.2500e-04
# Epoch 72/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 445.0641 - val_loss: 478.9593 - learning_rate: 1.2500e-04
# Epoch 73/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 466.3743 - val_loss: 480.5800 - learning_rate: 1.2500e-04
# Epoch 74/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 454.4214 - val_loss: 479.4948 - learning_rate: 1.2500e-04
# Epoch 75/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 448.1676 - val_loss: 478.3205 - learning_rate: 1.2500e-04
# Epoch 76/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 444.2762 - val_loss: 478.0465 - learning_rate: 1.2500e-04
# Epoch 77/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 445.0156 - val_loss: 478.1267 - learning_rate: 1.2500e-04
# Epoch 78/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 456.9209 - val_loss: 477.5707 - learning_rate: 1.2500e-04
# Epoch 79/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 433.2434 - val_loss: 477.0443 - learning_rate: 1.2500e-04
# Epoch 80/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 430.9703 - val_loss: 482.0558 - learning_rate: 1.2500e-04
# Epoch 81/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 434.9674 - val_loss: 477.6551 - learning_rate: 1.2500e-04
# Epoch 82/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 434.8128 - val_loss: 479.1120 - learning_rate: 1.2500e-04
# Epoch 83/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 443.0278 - val_loss: 477.4346 - learning_rate: 1.2500e-04
# Epoch 84/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 429.9841 - val_loss: 476.6435 - learning_rate: 1.2500e-04
# Epoch 85/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 422.9940 - val_loss: 476.9059 - learning_rate: 1.2500e-04
# Epoch 86/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 449.6978 - val_loss: 475.6909 - learning_rate: 1.2500e-04
# Epoch 87/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 447.7777 - val_loss: 476.6980 - learning_rate: 1.2500e-04
# Epoch 88/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 464.2280 - val_loss: 476.0273 - learning_rate: 1.2500e-04
# Epoch 89/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 442.8213 - val_loss: 474.7290 - learning_rate: 1.2500e-04
# Epoch 90/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 435.3394 - val_loss: 475.6089 - learning_rate: 1.2500e-04
# Epoch 91/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 439.0393 - val_loss: 474.3475 - learning_rate: 1.2500e-04
# Epoch 92/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 443.6920 - val_loss: 474.0740 - learning_rate: 1.2500e-04
# Epoch 93/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 438.9134 - val_loss: 474.4004 - learning_rate: 1.2500e-04
# Epoch 94/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 415.6186 - val_loss: 473.3317 - learning_rate: 1.2500e-04
# Epoch 95/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 436.3355 - val_loss: 475.9096 - learning_rate: 1.2500e-04
# Epoch 96/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 432.8407 - val_loss: 473.8011 - learning_rate: 1.2500e-04
# Epoch 97/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 434.8586 - val_loss: 472.8568 - learning_rate: 1.2500e-04
# Epoch 98/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 444.9207 - val_loss: 472.9073 - learning_rate: 1.2500e-04
# Epoch 99/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 427.9652 - val_loss: 475.1107 - learning_rate: 1.2500e-04
# Epoch 100/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 415.2492 - val_loss: 473.0615 - learning_rate: 1.2500e-04
# GRU training time: 206.92 seconds
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step

# %%
def average_model_performance(model_type, X_train, y_train, X_test, y_test, runs=3):
    rmses, mapes, maes, r2s = [], [], [], []
    for _ in range(runs):
        y_pred, _ = build_and_train_model(model_type, X_train, y_train, X_test, y_test)
        rmse, mape, mae, r2 = evaluate_model(y_test, y_pred, model_type)
        rmses.append(rmse)
        mapes.append(mape)
        maes.append(mae)
        r2s.append(r2)
    print(f"{model_type} average RMSE: {np.mean(rmses):.4f}, MAPE: {np.mean(mapes):.4f}, MAE: {np.mean(maes):.4f}, R²: {np.mean(r2s):.4f}")

# %%
def evaluate_model(y_true, y_pred, model_name):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"{model_name} - RMSE: {rmse:.4f}, MAPE: {mape:.4f}, MAE: {mae:.4f}, R² Score: {r2:.4f}")
    return rmse, mape, mae, r2

results = {
    "ANN": evaluate_model(y_test, y_pred_ann, "ANN"),
    "RNN": evaluate_model(y_test, y_pred_rnn, "RNN"),
    "LSTM": evaluate_model(y_test, y_pred_lstm, "LSTM"),
    "GRU": evaluate_model(y_test, y_pred_gru, "GRU")
}
# Out:
# ANN - RMSE: 21.8165, MAPE: 1.1552, MAE: 18.4706, R² Score: 0.0574
# RNN - RMSE: 20.5941, MAPE: 0.9170, MAE: 16.7315, R² Score: 0.1601
# LSTM - RMSE: 22.3278, MAPE: 1.2460, MAE: 19.2622, R² Score: 0.0127
# GRU - RMSE: 21.7453, MAPE: 1.1418, MAE: 18.3222, R² Score: 0.0635
